# %% [markdown]
# **Fine-tuning với tập dữ liệu văn bản pháp luật sử dụng pretrain model [BARTpho](https://huggingface.co/docs/transformers/model_doc/bartpho)**

# %% [markdown]
# Tải tải các môi trường cần thiết trước khi fine-turning

# %%
# Bị lỗi khi cài đặt bằng lệnh PIP nên mình thêm vào
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip -q install transformers torch accelerate SentencePiece

# %% [markdown]
# Load model

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoConfig

# huggingface token
access_token = "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"

# Load bộ tokenzier
tokenizer = AutoTokenizer.from_pretrained("vinai/bartpho-word",
                                          token=access_token)

# Cấu hình cho model
config = AutoConfig.from_pretrained("vinai/bartpho-word",
                                    trust_remote_code=True,
                                    token=access_token)
config.init_device = "cuda"
config.temperature = 0.1
config.max_length =300
config.eos_token_id=tokenizer.eos_token_id
config.pad_token_id=tokenizer.pad_token_id
config.do_sample = True

# Ld model
model = AutoModelForSeq2SeqLM.from_pretrained("vinai/bartpho-word",
                                              device_map="cuda",
                                              config=config,
                                              token=access_token)

# %%
input_text = 'Tóm tắt đoạn văn này: ChatGPT là một chatbot trí tuệ nhân tạo (AI) sử dụng xử lý ngôn ngữ tự nhiên để tạo ra cuộc trò chuyện giống như con người. Mô hình ngôn ngữ này có thể đáp ứng câu hỏi và sáng tác nhiều loại nội dung bằng văn bản, bao gồm bài viết, bài đăng trên mạng xã hội, bài luận, mã code và thư điện tử. ChatGPT là một dạng của trí tuệ nhân tạo tạo sinh - một công cụ cho phép người dùng nhập các yêu cầu để nhận được hình ảnh, văn bản hoặc video giống như con người được tạo ra bởi trí tuệ nhân tạo. ChatGPT tương tự như các dịch vụ chat tự động trên các trang web chăm sóc khách hàng, vì người dùng có thể đặt câu hỏi hoặc yêu cầu làm rõ các câu trả lời của ChatGPT. "GPT" là viết tắt của "Generative Pre-trained Transformer" đề cập đến cách ChatGPT xử lý yêu cầu và định hình câu trả lời. ChatGPT được đào tạo bằng cách sử dụng học tăng cường thông qua phản hồi từ con người và các mô hình thưởng xếp hạng câu trả lời tốt nhất. Phản hồi này giúp mô hình cải thiện khả năng đáp ứng trong tương lai.'

# Tokenizer đoạn văn bản trên
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

# Lấy output từ model
outputs = model.generate(input_ids)

# In ra output
print(tokenizer.decode(outputs[0]))

# %%
input_text = "Tôi đói, tôi muốn ăn một cái gì đó nóng, như:"

input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model.generate(input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# tensor([[   0, 1988,    9,  526,  196,  574,  408,   47,  177,  286,    2]],
#        device='cuda:0')
